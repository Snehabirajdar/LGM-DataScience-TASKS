# %% [markdown]
# **LetsGrowMore**...
#
# Beginner Level Task-2
#
# STOCK MARKET PREDICTION AND FORECASTING USING STACKED LSTM
#
# **Auther-Sneha Yashwant Birajdar**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
df = pd.read_csv("/content/NSE-TATAGLOBAL.csv")

# %%
df
# Out:
#             Date    Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 0     2018-09-28  234.05  235.95  ...  233.75               3069914          7162.35
# 1     2018-09-27  234.55  236.80  ...  233.25               5082859         11859.95
# 2     2018-09-26  240.00  240.00  ...  234.25               2240909          5248.60
# 3     2018-09-25  233.30  236.75  ...  236.10               2349368          5503.90
# 4     2018-09-24  233.55  239.20  ...  233.30               3423509          7999.55
# ...          ...     ...     ...  ...     ...                   ...              ...
# 2030  2010-07-27  117.60  119.50  ...  118.65                586100           694.98
# 2031  2010-07-26  120.10  121.00  ...  117.60                658440           780.01
# 2032  2010-07-23  121.80  121.95  ...  120.65                281312           340.31
# 2033  2010-07-22  120.30  122.00  ...  120.90                293312           355.17
# 2034  2010-07-21  122.10  123.00  ...  121.55                658666           803.56
#
# [2035 rows x 8 columns]

# %%
df.head()
# Out:
#          Date    Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 0  2018-09-28  234.05  235.95  ...  233.75               3069914          7162.35
# 1  2018-09-27  234.55  236.80  ...  233.25               5082859         11859.95
# 2  2018-09-26  240.00  240.00  ...  234.25               2240909          5248.60
# 3  2018-09-25  233.30  236.75  ...  236.10               2349368          5503.90
# 4  2018-09-24  233.55  239.20  ...  233.30               3423509          7999.55
#
# [5 rows x 8 columns]

# %%
df.tail()
# Out:
#             Date   Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 2030  2010-07-27  117.6  119.50  ...  118.65                586100           694.98
# 2031  2010-07-26  120.1  121.00  ...  117.60                658440           780.01
# 2032  2010-07-23  121.8  121.95  ...  120.65                281312           340.31
# 2033  2010-07-22  120.3  122.00  ...  120.90                293312           355.17
# 2034  2010-07-21  122.1  123.00  ...  121.55                658666           803.56
#
# [5 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
df.describe()
# Out:
#               Open         High  ...  Total Trade Quantity  Turnover (Lacs)
# count  2035.000000  2035.000000  ...          2.035000e+03      2035.000000
# mean    149.713735   151.992826  ...          2.335681e+06      3899.980565
# std      48.664509    49.413109  ...          2.091778e+06      4570.767877
# min      81.100000    82.800000  ...          3.961000e+04        37.040000
# 25%     120.025000   122.100000  ...          1.146444e+06      1427.460000
# 50%     141.500000   143.400000  ...          1.783456e+06      2512.030000
# 75%     157.175000   159.400000  ...          2.813594e+06      4539.015000
# max     327.700000   328.750000  ...          2.919102e+07     55755.080000
#
# [8 rows x 7 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Date                    datetime64[ns]
# Open                           float64
# High                           float64
# Low                            float64
# Last                           float64
# Close                          float64
# Total Trade Quantity             int64
# Turnover (Lacs)                float64
# dtype: object

# %%
df = df.sort_values('Date')
df.head()
# Out:
#            Date   Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 2034 2010-07-21  122.1  123.00  ...  121.55                658666           803.56
# 2033 2010-07-22  120.3  122.00  ...  120.90                293312           355.17
# 2032 2010-07-23  121.8  121.95  ...  120.65                281312           340.31
# 2031 2010-07-26  120.1  121.00  ...  117.60                658440           780.01
# 2030 2010-07-27  117.6  119.50  ...  118.65                586100           694.98
#
# [5 rows x 8 columns]

# %%
plt.figure(figsize = (9,6))
plt.title('Tata Stocks Closing Price')
plt.plot(data['Close'],'g')
plt.xlabel('Date',fontsize=15)
plt.ylabel('Close',fontsize=15)
# Out:
# Text(0, 0.5, 'Close')

# %%
dcorr = df.corr()
top_corr_features = dcorr.index
plt.figure(figsize=(10,7))
#plot heatmap
sns.heatmap(df[top_corr_features].corr(), annot=True, cmap="YlGnBu")

# %% [markdown]
# **MinMaxScaler**
#
# From the original dataset, we can tell that each of our target value are in close proximity to one another. So, we will use MinMaxScaler to scale down all the target variables in the range of (0, 1) for the ease of computation.

# %%
data_close = df.reset_index()['Close']
data_close.head()
scaler = MinMaxScaler(feature_range = (0, 1))
data_close = scaler.fit_transform(np.array(data_close).reshape(-1, 1))

# %%
#### Splitting train, Test data

# %%
train_size = int(len(data_close)*0.70)
test_size = len(data_close) - train_size
train, test = data_close[0 : train_size, :], data_close[train_size : len(data_close), :1]

# %%
def create_matrix(ds, time_step=1):
    dataX, dataY = [], []
    for i in range(len(ds)-time_step-1):
        a = ds[i:(i+time_step),0]
        dataX.append(a)
        dataY.append(ds[i+time_step,0])
    return np.array(dataX), np.array(dataY)

# %%
step=100 # time step
X_train, y_train = create_matrix(train, step)
X_test, y_test = create_matrix(test, step)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1323, 100) (1323,)
# (510, 100) (510,)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# **LSTM Model**

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, validation_split=0.1, epochs=77, batch_size=64, verbose=1, shuffle=True).history
# Out:
# Epoch 1/77
# 19/19 [==============================] - 11s 257ms/step - loss: 0.0102 - val_loss: 0.0015
# Epoch 2/77
# 19/19 [==============================] - 5s 253ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 3/77
# 19/19 [==============================] - 3s 179ms/step - loss: 8.6689e-04 - val_loss: 0.0011
# Epoch 4/77
# 19/19 [==============================] - 3s 178ms/step - loss: 8.0230e-04 - val_loss: 0.0010
# Epoch 5/77
# 19/19 [==============================] - 3s 179ms/step - loss: 7.7756e-04 - val_loss: 0.0010
# Epoch 6/77
# 19/19 [==============================] - 3s 185ms/step - loss: 7.4572e-04 - val_loss: 0.0010
# Epoch 7/77
# 19/19 [==============================] - 4s 219ms/step - loss: 7.4178e-04 - val_loss: 9.8877e-04
# Epoch 8/77
# 19/19 [==============================] - 3s 181ms/step - loss: 7.1610e-04 - val_loss: 9.3883e-04
# Epoch 9/77
# 19/19 [==============================] - 3s 182ms/step - loss: 7.0434e-04 - val_loss: 9.0717e-04
# Epoch 10/77
# 19/19 [==============================] - 3s 184ms/step - loss: 6.8376e-04 - val_loss: 8.4135e-04
# Epoch 11/77
# 19/19 [==============================] - 3s 182ms/step - loss: 6.6672e-04 - val_loss: 7.8425e-04
# Epoch 12/77
# 19/19 [==============================] - 3s 181ms/step - loss: 6.6728e-04 - val_loss: 8.5640e-04
# Epoch 13/77
# 19/19 [==============================] - 3s 182ms/step - loss: 6.3154e-04 - val_loss: 7.6961e-04
# Epoch 14/77
# 19/19 [==============================] - 3s 182ms/step - loss: 6.0164e-04 - val_loss: 6.9366e-04
# Epoch 15/77
# 19/19 [==============================] - 3s 179ms/step - loss: 5.8066e-04 - val_loss: 6.6496e-04
# Epoch 16/77
# 19/19 [==============================] - 3s 182ms/step - loss: 5.7488e-04 - val_loss: 6.2409e-04
# Epoch 17/77
# 19/19 [==============================] - 3s 184ms/step - loss: 5.8309e-04 - val_loss: 6.8675e-04
# Epoch 18/77
# 19/19 [==============================] - 4s 184ms/step - loss: 5.7349e-04 - val_loss: 6.0899e-04
# Epoch 19/77
# 19/19 [==============================] - 4s 185ms/step - loss: 5.8388e-04 - val_loss: 5.9322e-04
# Epoch 20/77
# 19/19 [==============================] - 3s 183ms/step - loss: 5.5644e-04 - val_loss: 6.7510e-04
# Epoch 21/77
# 19/19 [==============================] - 4s 212ms/step - loss: 5.6411e-04 - val_loss: 5.5452e-04
# Epoch 22/77
# 19/19 [==============================] - 3s 179ms/step - loss: 5.3539e-04 - val_loss: 5.3975e-04
# Epoch 23/77
# 19/19 [==============================] - 3s 180ms/step - loss: 5.2790e-04 - val_loss: 5.3770e-04
# Epoch 24/77
# 19/19 [==============================] - 3s 183ms/step - loss: 4.7947e-04 - val_loss: 5.1687e-04
# Epoch 25/77
# 19/19 [==============================] - 3s 180ms/step - loss: 4.8605e-04 - val_loss: 5.0996e-04
# Epoch 26/77
# 19/19 [==============================] - 3s 180ms/step - loss: 4.7253e-04 - val_loss: 4.6998e-04
# Epoch 27/77
# 19/19 [==============================] - 3s 179ms/step - loss: 4.6120e-04 - val_loss: 4.5706e-04
# Epoch 28/77
# 19/19 [==============================] - 3s 180ms/step - loss: 4.4942e-04 - val_loss: 4.4356e-04
# Epoch 29/77
# 19/19 [==============================] - 3s 176ms/step - loss: 4.3963e-04 - val_loss: 4.9371e-04
# Epoch 30/77
# 19/19 [==============================] - 3s 179ms/step - loss: 4.2154e-04 - val_loss: 4.1638e-04
# Epoch 31/77
# 19/19 [==============================] - 3s 183ms/step - loss: 4.7457e-04 - val_loss: 4.5819e-04
# Epoch 32/77
# 19/19 [==============================] - 4s 187ms/step - loss: 4.0867e-04 - val_loss: 5.0706e-04
# Epoch 33/77
# 19/19 [==============================] - 4s 185ms/step - loss: 3.8762e-04 - val_loss: 4.3074e-04
# Epoch 34/77
# 19/19 [==============================] - 4s 187ms/step - loss: 3.7661e-04 - val_loss: 3.6650e-04
# Epoch 35/77
# 19/19 [==============================] - 3s 182ms/step - loss: 3.9706e-04 - val_loss: 3.8463e-04
# Epoch 36/77
# 19/19 [==============================] - 3s 180ms/step - loss: 3.5962e-04 - val_loss: 4.3217e-04
# Epoch 37/77
# 19/19 [==============================] - 3s 182ms/step - loss: 3.7442e-04 - val_loss: 3.9570e-04
# Epoch 38/77
# 19/19 [==============================] - 3s 180ms/step - loss: 3.5021e-04 - val_loss: 3.9941e-04
# Epoch 39/77
# 19/19 [==============================] - 3s 182ms/step - loss: 3.4240e-04 - val_loss: 3.1898e-04
# Epoch 40/77
# 19/19 [==============================] - 3s 183ms/step - loss: 3.3321e-04 - val_loss: 3.2111e-04
# Epoch 41/77
# 19/19 [==============================] - 3s 179ms/step - loss: 3.7851e-04 - val_loss: 3.5154e-04
# Epoch 42/77
# 19/19 [==============================] - 3s 183ms/step - loss: 3.4640e-04 - val_loss: 3.5605e-04
# Epoch 43/77
# 19/19 [==============================] - 3s 184ms/step - loss: 3.0358e-04 - val_loss: 2.8347e-04
# Epoch 44/77
# 19/19 [==============================] - 3s 178ms/step - loss: 2.9875e-04 - val_loss: 2.7757e-04
# Epoch 45/77
# 19/19 [==============================] - 3s 180ms/step - loss: 2.8907e-04 - val_loss: 2.7172e-04
# Epoch 46/77
# 19/19 [==============================] - 3s 180ms/step - loss: 2.8169e-04 - val_loss: 2.5707e-04
# Epoch 47/77
# 19/19 [==============================] - 3s 179ms/step - loss: 2.7515e-04 - val_loss: 2.4490e-04
# Epoch 48/77
# 19/19 [==============================] - 3s 181ms/step - loss: 3.0651e-04 - val_loss: 3.5234e-04
# Epoch 49/77
# 19/19 [==============================] - 3s 183ms/step - loss: 2.9786e-04 - val_loss: 2.4072e-04
# Epoch 50/77
# 19/19 [==============================] - 3s 181ms/step - loss: 2.8078e-04 - val_loss: 2.4344e-04
# Epoch 51/77
# 19/19 [==============================] - 3s 183ms/step - loss: 2.6145e-04 - val_loss: 2.2224e-04
# Epoch 52/77
# 19/19 [==============================] - 3s 179ms/step - loss: 2.5164e-04 - val_loss: 2.1773e-04
# Epoch 53/77
# 19/19 [==============================] - 3s 181ms/step - loss: 2.4167e-04 - val_loss: 2.1792e-04
# Epoch 54/77
# 19/19 [==============================] - 3s 183ms/step - loss: 2.3861e-04 - val_loss: 2.3539e-04
# Epoch 55/77
# 19/19 [==============================] - 4s 188ms/step - loss: 2.2635e-04 - val_loss: 2.4657e-04
# Epoch 56/77
# 19/19 [==============================] - 3s 179ms/step - loss: 2.6390e-04 - val_loss: 2.3220e-04
# Epoch 57/77
# 19/19 [==============================] - 4s 186ms/step - loss: 2.2147e-04 - val_loss: 2.0435e-04
# Epoch 58/77
# 19/19 [==============================] - 3s 178ms/step - loss: 2.2579e-04 - val_loss: 1.9088e-04
# Epoch 59/77
# 19/19 [==============================] - 3s 181ms/step - loss: 2.1347e-04 - val_loss: 1.7866e-04
# Epoch 60/77
# 19/19 [==============================] - 3s 183ms/step - loss: 2.1605e-04 - val_loss: 1.8840e-04
# Epoch 61/77
# 19/19 [==============================] - 3s 179ms/step - loss: 2.0471e-04 - val_loss: 1.9754e-04
# Epoch 62/77
# 19/19 [==============================] - 3s 183ms/step - loss: 2.2552e-04 - val_loss: 1.7571e-04
# Epoch 63/77
# 19/19 [==============================] - 3s 181ms/step - loss: 1.9202e-04 - val_loss: 1.7850e-04
# Epoch 64/77
# 19/19 [==============================] - 3s 176ms/step - loss: 2.0842e-04 - val_loss: 1.6271e-04
# Epoch 65/77
# 19/19 [==============================] - 3s 178ms/step - loss: 1.8915e-04 - val_loss: 1.6703e-04
# Epoch 66/77
# 19/19 [==============================] - 3s 178ms/step - loss: 1.8981e-04 - val_loss: 1.6225e-04
# Epoch 67/77
# 19/19 [==============================] - 3s 183ms/step - loss: 1.8906e-04 - val_loss: 1.7004e-04
# Epoch 68/77
# 19/19 [==============================] - 3s 182ms/step - loss: 1.9230e-04 - val_loss: 1.7230e-04
# Epoch 69/77
# 19/19 [==============================] - 3s 177ms/step - loss: 1.7420e-04 - val_loss: 1.6959e-04
# Epoch 70/77
# 19/19 [==============================] - 3s 178ms/step - loss: 1.7562e-04 - val_loss: 1.4915e-04
# Epoch 71/77
# 19/19 [==============================] - 3s 180ms/step - loss: 1.7393e-04 - val_loss: 1.4369e-04
# Epoch 72/77
# 19/19 [==============================] - 3s 179ms/step - loss: 1.5956e-04 - val_loss: 1.5506e-04
# Epoch 73/77
# 19/19 [==============================] - 3s 180ms/step - loss: 1.6162e-04 - val_loss: 1.3890e-04
# Epoch 74/77
# 19/19 [==============================] - 3s 183ms/step - loss: 1.7060e-04 - val_loss: 1.3266e-04
# Epoch 75/77
# 19/19 [==============================] - 3s 180ms/step - loss: 1.7046e-04 - val_loss: 2.5429e-04
# Epoch 76/77
# 19/19 [==============================] - 3s 184ms/step - loss: 1.7243e-04 - val_loss: 1.3555e-04
# Epoch 77/77
# 19/19 [==============================] - 3s 183ms/step - loss: 1.5458e-04 - val_loss: 1.3873e-04

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# %%
# Reversing the MinMax Scaler
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
### Visualise the Predictions
look_back = 100
train_num_pyredict_plot = np.empty_like(data_close)
train_num_pyredict_plot[:, :] = np.nan
train_num_pyredict_plot[look_back : len(train_predict) + look_back, :] = train_predict
test_predict_plot = np.empty_like(data_close)
test_predict_plot[:, :] = np.nan
test_predict_plot[len(train_predict) + (look_back * 2) + 1 : len(data_close) - 1, :] = test_predict
plt.plot(scaler.inverse_transform(data_close))
plt.plot(train_num_pyredict_plot)
plt.plot(test_predict_plot)
plt.show()

# %%
### Future Prediction Model
x_inum_pyut=test[307:].reshape(1, -1)
x_inum_pyut.shape
temp_inum_pyut = list(x_inum_pyut)
temp_inum_pyut = temp_inum_pyut[0].tolist()
temp_inum_pyut = list(x_inum_pyut)
temp_inum_pyut = temp_inum_pyut[0].tolist()

# %%
day_new = np.arange(1, 101)
day_pred = np.arange(101, 131)
plt.plot(day_new, scaler.inverse_transform(data_close[1935 : ]))

# %% [markdown]
# **Thank You!!**
